# %%
#EDA Project
import pandas as pd #install all packages
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
life_span = pd.read_csv("Life Expectancy Data.csv", encoding='ISO-8859-1') #load the CSV

# %%
life_span.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life_span.info
# Out:
# <bound method DataFrame.info of           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
life_span.isnull().sum() #check for null values
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
life_span.dropna(inplace=True) #remove null values.

# %%
life_span.isnull().sum()
# Out:
# Country                   0
# Year                      0
# Status                    0
# Life expectancy           0
# Adult Mortality           0
# infant deaths             0
# percentage expenditure    0
# Measles                   0
#  BMI                      0
# under-five deaths         0
# Polio                     0
# Diphtheria                0
#  HIV/AIDS                 0
# GDP                       0
#  thinness  1-19 years     0
#  thinness 5-9 years       0
# Schooling                 0
# Row_ID                    0
# Continent                 0
# dtype: int64

# %%
life_span.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  1649.000000       1649.000000      1649.000000    1649.000000
# mean   2007.840509         69.302304       168.215282      32.553062
# std       4.087711          8.796834       125.310417     120.847190
# min    2000.000000         44.000000         1.000000       0.000000
# 25%    2005.000000         64.400000        77.000000       1.000000
# 50%    2008.000000         71.700000       148.000000       3.000000
# 75%    2011.000000         75.000000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
#Countries with the highest life expectancy
country_vs_life = life_span.groupby('Country', as_index=False)['Life expectancy '].mean()
country_vs_life.sort_values(by = 'Life expectancy ', ascending=False).head(10)
# Out:
#          Country  Life expectancy
# 58       Ireland         83.440000
# 24        Canada         82.233333
# 43        France         82.206667
# 60         Italy         82.153333
# 111        Spain         82.020000
# 6      Australia         81.907143
# 115       Sweden         81.900000
# 7        Austria         81.480000
# 88   Netherlands         81.325000
# 48        Greece         81.233333

# %%
#Countries with the lowest life expectancy
country_vs_life.sort_values(by = 'Life expectancy ', ascending = True).head(10)
# Out:
#                       Country  Life expectancy
# 108              Sierra Leone         48.425000
# 68                    Lesotho         48.608333
# 132                  Zimbabwe         49.386667
# 73                     Malawi         50.261538
# 3                      Angola         50.675000
# 114                 Swaziland         50.820000
# 25   Central African Republic         51.416667
# 26                       Chad         52.285714
# 91                    Nigeria         52.840000
# 84                 Mozambique         53.407143

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Distplot-depicts the variation in the data distribution
count = 1

fig = plt.figure(figsize = [20, 10])
cols = life_span.select_dtypes(exclude=['object']).columns.tolist()

for col in cols:
    plt.subplot(5, 4, count)
    sns.distplot(life_span[col], hist_kws=dict(edgecolor="k", linewidth=1, color='blue'), color='red')
    count += 1
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vj/c_tlc1m11fqcj9xpngblj6_h0000gn/T/ipykernel_20996/3081086825.py:9: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /var/folders/vj/c_tlc1m11fqcj9xpngblj6_h0000gn/T/ipykernel_20996/3081086825.py:9: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
#Box and whisker plot-showing the distribution of data points across a selected measure
#this is helpful with identifying the outliers and compare the data across several categories.
count = 1

fig = plt.figure(figsize = [20, 10])
cols = life_span.select_dtypes(exclude=['object']).columns.tolist()

for col in cols:
    plt.subplot(5, 4, count)
    sns.boxplot(x = life_span[col])
    count += 1
plt.tight_layout()
plt.show()

# %%
pip install pycountry_convert
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy import stats
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2

# %%
#Bubble chart to  visualize Life Expectancy vs GDP Plot. 
#Where size of the bubble determines the population of that particular country and 
#color denotes the continent of the country.
continents = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU': 'Europe'
}
continent = []
for country in life_span['Country']:
    try:
        continent.append(continents[(country_alpha2_to_continent_code(country_name_to_country_alpha2(country)))])
    except:
        continent.append("Africa")
    
life_span["Continent"] = continent
to_bubble = life_span[["Country", "Year", "Life expectancy ", "GDP", "Population", "Continent"]]

# %%
to_bubble
# Out:
#           Country  Year  Life expectancy          GDP  Population Continent
# 0     Afghanistan  2015              65.0  584.259210  33736494.0      Asia
# 1     Afghanistan  2014              59.9  612.696514    327582.0      Asia
# 2     Afghanistan  2013              59.9  631.744976  31731688.0      Asia
# 3     Afghanistan  2012              59.5  669.959000   3696958.0      Asia
# 4     Afghanistan  2011              59.2   63.537231   2978599.0      Asia
# ...           ...   ...               ...         ...         ...       ...
# 2933     Zimbabwe  2004              44.3  454.366654  12777511.0    Africa
# 2934     Zimbabwe  2003              44.5  453.351155  12633897.0    Africa
# 2935     Zimbabwe  2002              44.8   57.348340    125525.0    Africa
# 2936     Zimbabwe  2001              45.3  548.587312  12366165.0    Africa
# 2937     Zimbabwe  2000              46.0  547.358878  12222251.0    Africa
#
# [1649 rows x 6 columns]

# %%
#Countries with high GDP(gross domestic product) also have a high life expectancy rate than countries with low GDP.
#most African countries have low expectancy rate.
#Continent codes were created and the countries in the table were then grouped by continent.

# %%
d = to_bubble.drop('Year', axis=1)
to_bubble = d.groupby(['Country', 'Continent']).mean().reset_index()
to_bubble['GDP'] = np.log10(to_bubble['GDP'])
to_bubble.head()
# Out:
# /Users/bigmeech/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                Country      Continent  Life expectancy        GDP
# 0          Afghanistan           Asia         58.171429  2.553536
# 1              Albania         Europe         74.885714  3.250141
# 2              Algeria         Africa         73.618750  3.454511
# 3               Angola         Africa         49.018750  3.295608
# 4  Antigua and Barbuda  North America         75.056250  3.989416

# %%
#Bubble Visualization
import plotly.express as px

# %%
df = px.data.gapminder()

fig = px.scatter(to_bubble, x="GDP", y="Life expectancy ",
                 size="Population", color="Continent",
                 hover_name="Country", log_x=True, size_max=50)
fig.show()
# Out:
# <div>                            <div id="87bd6707-3716-4bb1-8592-1b699e09185d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87bd6707-3716-4bb1-8592-1b699e09185d")) {                    Plotly.newPlot(                        "87bd6707-3716-4bb1-8592-1b699e09185d",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Continent=Asia<br>GDP=%{x}<br>Life expectancy =%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia
# ...

# %%
#Identified outliers with the Box plot, not it is time to remove them.
Q1 = life_span[cols].quantile(0.25)
Q3 = life_span[cols].quantile(0.75)
IQR = Q3 - Q1

outliers = ((life_span[cols] < (Q1 - 1.7 * IQR)) | (life_span[cols] > (Q3 + 1.7 * IQR))).any(axis=1)

life_span = life_span[~outliers]

life_span.head()
# Out:
#     Country  Year      Status  Life expectancy   Adult Mortality  \
# 16  Albania  2022  Developing              77.8               74
# 18  Albania  2020  Developing              77.2               84
# 19  Albania  2019  Developing              76.9               86
# 21  Albania  2017  Developing              76.2               91
# 22  Albania  2016  Developing              76.1               91
#
#     infant deaths  percentage expenditure  Measles    BMI   \
# 16              0                   365.0         0   58.0
# 18              0                   430.9         0   56.5
# 19              0                   412.4         9   55.8
# 21              1                    41.8        10   54.3
# 22              1                   348.1         0   53.5
#
#     under-five deaths   Polio  Diphtheria    HIV/AIDS   GDP  \
# 16                   0     99           99        0.1  3954
# 18                   1     99           99        0.1  4415
# ...

# %%
life_span
# Out:
#       Country  Year      Status  Life expectancy   Adult Mortality  \
# 16    Albania  2022  Developing              77.8               74
# 18    Albania  2020  Developing              77.2               84
# 19    Albania  2019  Developing              76.9               86
# 21    Albania  2017  Developing              76.2               91
# 22    Albania  2016  Developing              76.1               91
# ...       ...   ...         ...               ...              ...
# 2899    Yemen  2015  Developing              63.8              238
# 2900    Yemen  2014  Developing              63.4               24
# 2905    Yemen  2009  Developing              61.5               25
# 2906    Yemen  2008  Developing              61.1              251
# 2907    Yemen  2007  Developing              68.0              252
#
#       infant deaths  percentage expenditure  Measles    BMI   \
# 16                0                   365.0         0   58.0
# ...

# %%
to_bubble
# Out:
#           Country  Year  Life expectancy          GDP  Population Continent
# 0     Afghanistan  2015              65.0  584.259210  33736494.0      Asia
# 1     Afghanistan  2014              59.9  612.696514    327582.0      Asia
# 2     Afghanistan  2013              59.9  631.744976  31731688.0      Asia
# 3     Afghanistan  2012              59.5  669.959000   3696958.0      Asia
# 4     Afghanistan  2011              59.2   63.537231   2978599.0      Asia
# ...           ...   ...               ...         ...         ...       ...
# 2933     Zimbabwe  2004              44.3  454.366654  12777511.0    Africa
# 2934     Zimbabwe  2003              44.5  453.351155  12633897.0    Africa
# 2935     Zimbabwe  2002              44.8   57.348340    125525.0    Africa
# 2936     Zimbabwe  2001              45.3  548.587312  12366165.0    Africa
# 2937     Zimbabwe  2000              46.0  547.358878  12222251.0    Africa
#
# [1649 rows x 6 columns]

# %%
#Infant/adult mortality, and disease all have negative correlation with life expectancy while
#there is a positive correlation for those that have been vaccinated, have higher income, and schooling.
l= [life_span['Life expectancy '].dropna(), life_span['Income composition of resources'].dropna(), life_span['Schooling'].dropna()]
for i in l:
    plt.figure(figsize=(20,5))
    sns.histplot(i, kde=True, color="orange")

# %%
nr_rows = 5
nr_cols = 4

fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*5,nr_rows*5))
numerical_feats = life_span.dtypes[life_span.dtypes != "object"].index
li_num_feats = list(numerical_feats)
li_not_plot = []
li_plot_num_feats = [c for c in list(numerical_feats) if c not in li_not_plot]
life_span.dropna(inplace = True)

for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        i = r*nr_cols+c
        if i < len(li_plot_num_feats):
            sns.regplot(x = life_span[li_plot_num_feats[i]],y = life_span["Life expectancy "] , color = 'blue', ax = axs[r][c])
            stp = stats.pearsonr(life_span[li_plot_num_feats[i]], life_span["Life expectancy "])
            str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
            axs[r][c].set_title(str_title,fontsize=11)
            
            
plt.tight_layout()    
sns.set(color_codes=True)

# %%
plt.show();

# %%
#The above dot/subplot shows the correlation between diff categories and life expect
#Alcohol surprisingly has a positive correlation on l.e, along with countries that are richer with lower population.
#Africa is the only country not affected by alcoholism.

# %%
fig, axs = plt.subplots(2,3, figsize=(15, 6), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.5)

for conts, ax in zip(set(life_span["Continent"]), axs.flat):
    Conts = life_span[life_span['Continent'] == conts]
    sns.regplot(x = Conts['Alcohol'],y = Conts["Life expectancy "], color = 'red', ax = ax).set_title(conts)

plt.tight_layout()    
sns.set(color_codes=True)
plt.show()

# %%
alcohol_consumption = pd.read_csv("drinks.csv", encoding='ISO-8859-1')

# %%
alcohol_consumption
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
type(alcohol_consumption)
# Out:
# pandas.core.frame.DataFrame

# %%
alcohol_consumption.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
alcohol_consumption.info() #colums, Non Null and Dtype in the df.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   Continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
alcohol_consumption.isnull().sum() #No null values shown
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# Continent                       0
# dtype: int64

# %%
alcohol_consumption.nunique() #all of the unique values
# Out:
# country                         193
# beer_servings                   130
# spirit_servings                 109
# wine_servings                    79
# total_litres_of_pure_alcohol     90
# Continent                         6
# dtype: int64

# %%
alcohol_consumption.corr
# Out:
# <bound method DataFrame.corr of          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      Continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
count = 1

fig = plt.figure(figsize = [20, 10])
cols = alcohol_consumption.select_dtypes(exclude=['object']).columns.tolist()

for col in cols:
    plt.subplot(5, 4, count)
    sns.distplot(alcohol_consumption[col], hist_kws=dict(edgecolor="k", linewidth=1, color='blue'), color='red')
    count += 1
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vj/c_tlc1m11fqcj9xpngblj6_h0000gn/T/ipykernel_20996/447763687.py:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /var/folders/vj/c_tlc1m11fqcj9xpngblj6_h0000gn/T/ipykernel_20996/447763687.py:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
count = 1

fig = plt.figure(figsize = [20, 10])
cols = alcohol_consumption.select_dtypes(exclude=['object']).columns.tolist()

for col in cols:
    plt.subplot(5, 4, count)
    sns.boxplot(x = alcohol_consumption[col])
    count += 1
plt.tight_layout()
plt.show()

# %%
alcohol_consumption
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 0                 Afghanistan              0                0              0
# 13                 Bangladesh              0                0              0
# 19                     Bhutan             23                0              0
# 24                     Brunei             31                2              1
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# 38                    Comoros              1                3              1
# 39                      Congo             76                1              9
# 46                North Korea              0                0              0
# 47                   DR Congo             32                3              1
# 53                      Egypt              6                4              1
# ...

# %%
#I removed all the countries with 0 alcohol consumption. 

dry_country = alcohol_consumption.columns[1:-1]  # assuming 'Country' is the first column and 'Continent' is the last

# Create a boolean mask where each cell is True if the value is 0
mask = alcohol_consumption[dry_country].eq(0).all(axis=1)

# Use the mask to filter out rows with all zeros
filtered_alc_con = alcohol_consumption[~mask]

# %%
filtered_alc_con #using the filtered DF moving forward.
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 19                     Bhutan             23                0              0
# 24                     Brunei             31                2              1
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# 38                    Comoros              1                3              1
# 39                      Congo             76                1              9
# 47                   DR Congo             32                3              1
# 53                      Egypt              6                4              1
# 56                    Eritrea             18                0              0
# 58                   Ethiopia             20                3              0
# 59                       Fiji             77               35              1
# ...

# %%
#My next goal is to add the consumption amount for all the alcohol types into one column and order
#by the country in DESC order.

# Create a new column 'Total' which is the sum of the specified columns
filtered_alc_con['Total'] = filtered_alc_con[['beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol']].sum(axis=1)
# Out:
# /var/folders/vj/c_tlc1m11fqcj9xpngblj6_h0000gn/T/ipykernel_20996/1355223050.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sorted_df = filtered_alc_con.sort_values(by='Total', ascending=False)

# %%
sorted_df
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 59                       Fiji             77               35              1
# 95                    Lesotho             82               29              0
# 39                      Congo             76                1              9
# 131          Papua New Guinea             44               39              1
# 154                 Singapore             60               12             11
# 88                      Kenya             58               22              2
# 176                    Turkey             51               22              7
# 115                Mozambique             47               18              5
# 157           Solomon Islands             56               11              1
# 173                     Tonga             36               21              5
# 118                     Nauru             49                0              8
# ...
